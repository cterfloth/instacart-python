# %% [markdown]
# ### 01. Import libraries and data

# %%
#Import libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'/Users/Cel/Documents/Data Analytics/09-2023 Instacart Basket Analysis'

# %%
#Import orders products prior data frame
df_ords_prior = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders_products_prior.csv'))

# %%
#Import orders data frame
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_checked.csv'))

# %%
#Check outputs
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
df_ords.head()
# Out:
#    Unnamed: 0  order_id  user_id  number_of_orders  orders_day_of_week  \
# 0           0   2539329        1                 1                   2
# 1           1   2398795        1                 2                   3
# 2           2    473747        1                 3                   3
# 3           3   2254736        1                 4                   4
# 4           4    431534        1                 5                   4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
df_ords.shape
# Out:
# (3421083, 7)

# %% [markdown]
# ### 02. Merging data

# %%
#Merge data frames using 'order_id' as key
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
df_merged_large
# Out:
#           Unnamed: 0  order_id  user_id  number_of_orders  orders_day_of_week  \
# 0                  0   2539329        1                 1                   2
# 1                  0   2539329        1                 1                   2
# 2                  0   2539329        1                 1                   2
# 3                  0   2539329        1                 1                   2
# 4                  0   2539329        1                 1                   2
# ...              ...       ...      ...               ...                 ...
# 32434484     3421081   2977660   206209                13                   1
# 32434485     3421081   2977660   206209                13                   1
# 32434486     3421081   2977660   206209                13                   1
# 32434487     3421081   2977660   206209                13                   1
# 32434488     3421081   2977660   206209                13                   1
#
# ...

# %%
#Check value counts in indicator column '_merge' 
df_merged_large['_merge'].value_counts()
# Out:
# _merge
# both          32434489
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# ### 03. Export as pickle file

# %%
df_merged_large.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.pkl'))
