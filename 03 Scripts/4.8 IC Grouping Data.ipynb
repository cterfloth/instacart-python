# %% [markdown]
# ### 01. Environment Setup

# %%
#Import libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'/Users/Cel/Documents/Data Analytics/09-2023 Instacart Basket Analysis'

# %%
#Import file
ords_prods_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_derived_columns.pkl'))

# %%
#Create df with first 1000000 rows
df = ords_prods_merged[:1000000]

# %%
#Check shape
df.shape
# Out:
# (1000000, 18)

# %%
#Check columns
df.head()
# Out:
#    order_id  user_id  number_of_orders  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1                 1                   2                  8
# 1   2398795        1                 2                   3                  7
# 2    473747        1                 3                   3                 12
# 3   2254736        1                 4                   4                  7
# 4    431534        1                 5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# 0         Soda        77              7     9.0   both  Mid-range product
# 1         Soda        77              7     9.0   both  Mid-range product
# 2         Soda        77              7     9.0   both  Mid-range product
# 3         Soda        77              7     9.0   both  Mid-range product
# 4         Soda        77              7     9.0   both  Mid-range product
#
#   busiest_period_of_day     busiest_day two_busiest_days
# 0        Average orders  Regularly busy   Regularly busy
# 1        Average orders  Regularly busy  Least busy days
# 2           Most orders  Regularly busy  Least busy days
# 3        Average orders      Least busy  Least busy days
# 4           Most orders      Least busy  Least busy days

# %% [markdown]
# ### 02. Single Aggregations

# %%
#Group by functions
df.groupby('product_name')

# %% [markdown]
# The groupby function needs more arguments

# %%
#Need to split data into groups, then apply the agg function to each group
df.groupby('department_id').agg({'number_of_orders': ['mean']})
# Out:
#               number_of_orders
#                           mean
# department_id
# 4                    18.825780
# 7                    17.472355
# 13                   17.993423
# 14                   19.246334
# 16                   19.463012
# 17                   11.294069
# 19                   19.305237
# 20                   17.599636

# %% [markdown]
# ### 03. Multiple Aggregations

# %%
#Simply add more arguments to agg function
df.groupby('department_id').agg({'number_of_orders': ['mean', 'min', 'max']})
# Out:
#               number_of_orders
#                           mean min max
# department_id
# 4                    18.825780   1  99
# 7                    17.472355   1  99
# 13                   17.993423   1  99
# 14                   19.246334   1  99
# 16                   19.463012   1  99
# 17                   11.294069   1  98
# 19                   19.305237   1  99
# 20                   17.599636   1  99

# %% [markdown]
# ### 04. Aggregate Data with transform() function

# %%
#Create new column 'max_order' - aggregate number of orders per user_id
ords_prods_merged['max_order'] = ords_prods_merged.groupby(['user_id'])['number_of_orders'].transform(np.max)

# %%
ords_prods_merged.head(100)
# Out:
#     order_id  user_id  number_of_orders  orders_day_of_week  \
# 0    2539329        1                 1                   2
# 1    2398795        1                 2                   3
# 2     473747        1                 3                   3
# 3    2254736        1                 4                   4
# 4     431534        1                 5                   4
# ..       ...      ...               ...                 ...
# 95   3226575      360                 1                   5
# 96   1469869      377                 3                   5
# 97   1927023      387                 2                   4
# 98    858092      420                 4                   1
# 99    119314      420                 5                   3
#
#     order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                   8                     NaN         196                  1
# 1                   7                    15.0         196                  1
# 2                  12                    21.0         196                  1
# 3                   7                    29.0         196                  1
# 4                  15                    28.0         196                  1
# ..                ...                     ...         ...                ...
# 95                 12                     NaN         196                  1
# 96                 17                     3.0         196                  9
# 97                 10                    22.0         196                  3
# 98                 19                    30.0         196                  2
# 99                 19                    16.0         196                  2
#
#     reordered product_name  aisle_id  department_id  prices _merge  \
# 0           0         Soda        77              7     9.0   both
# 1           1         Soda        77              7     9.0   both
# 2           1         Soda        77              7     9.0   both
# 3           1         Soda        77              7     9.0   both
# 4           1         Soda        77              7     9.0   both
# ..        ...          ...       ...            ...     ...    ...
# 95          0         Soda        77              7     9.0   both
# 96          0         Soda        77              7     9.0   both
# 97          0         Soda        77              7     9.0   both
# 98          0         Soda        77              7     9.0   both
# 99          1         Soda        77              7     9.0   both
#
#       price_range_loc busiest_period_of_day     busiest_day two_busiest_days  \
# 0   Mid-range product        Average orders  Regularly busy   Regularly busy
# 1   Mid-range product        Average orders  Regularly busy  Least busy days
# 2   Mid-range product           Most orders  Regularly busy  Least busy days
# 3   Mid-range product        Average orders      Least busy  Least busy days
# 4   Mid-range product           Most orders      Least busy  Least busy days
# ..                ...                   ...             ...              ...
# 95  Mid-range product           Most orders  Regularly busy   Regularly busy
# 96  Mid-range product        Average orders  Regularly busy   Regularly busy
# 97  Mid-range product           Most orders      Least busy  Least busy days
# 98  Mid-range product        Average orders  Regularly busy     Busiest days
# 99  Mid-range product        Average orders  Regularly busy  Least busy days
#
#     max_order
# 0          10
# 1          10
# 2          10
# 3          10
# 4          10
# ..        ...
# 95          3
# 96          3
# 97          8
# 98         22
# 99         22
#
# [100 rows x 19 columns]

# %%
#Change pandas settings to allow unlimited rows to be displayed, then check first 100 rows
pd.options.display.max_rows = None

# %% [markdown]
# ### 05. Derive new column from 'max_order'

# %%
#Create a flag that assigns a loyalty value based on 'max_order'
ords_prods_merged.loc[ords_prods_merged['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merged.loc[(ords_prods_merged['max_order'] <= 40) & (ords_prods_merged['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merged.loc[ords_prods_merged['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
#Check frequency counts
ords_prods_merged['loyalty_flag'].value_counts()
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
#Index first 60 rows of user_id, loyalty_flag, number_of_orders
ords_prods_merged[['user_id', 'loyalty_flag', 'number_of_orders']].head(60)
# Out:
#     user_id      loyalty_flag  number_of_orders
# 0         1      New customer                 1
# 1         1      New customer                 2
# 2         1      New customer                 3
# 3         1      New customer                 4
# 4         1      New customer                 5
# 5         1      New customer                 6
# 6         1      New customer                 7
# 7         1      New customer                 8
# 8         1      New customer                 9
# 9         1      New customer                10
# 10       15  Regular customer                15
# 11       15  Regular customer                17
# 12       15  Regular customer                18
# 13       15  Regular customer                21
# 14       15  Regular customer                22
# 15       19      New customer                 2
# 16       19      New customer                 5
# 17       19      New customer                 7
# 18       21  Regular customer                10
# 19       31  Regular customer                10
# 20       31  Regular customer                17
# 21       43  Regular customer                 6
# 22       43  Regular customer                 9
# 23       52  Regular customer                 1
# 24       52  Regular customer                 2
# 25       52  Regular customer                 3
# 26       52  Regular customer                 5
# 27       52  Regular customer                 7
# 28       52  Regular customer                 9
# 29       52  Regular customer                10
# 30       52  Regular customer                11
# 31       52  Regular customer                12
# 32       52  Regular customer                15
# 33       52  Regular customer                17
# 34       52  Regular customer                18
# 35       52  Regular customer                19
# 36       52  Regular customer                21
# 37       67  Regular customer                 1
# 38       67  Regular customer                 2
# 39       67  Regular customer                 3
# 40       67  Regular customer                 4
# 41       67  Regular customer                 5
# 42       67  Regular customer                 6
# 43       67  Regular customer                 8
# 44       67  Regular customer                 9
# 45       67  Regular customer                10
# 46       67  Regular customer                11
# 47       67  Regular customer                12
# 48       67  Regular customer                13
# 49       67  Regular customer                14
# 50       67  Regular customer                16
# 51       67  Regular customer                18
# 52       67  Regular customer                19
# 53       67  Regular customer                21
# 54       67  Regular customer                22
# 55       67  Regular customer                23
# 56       81      New customer                 3
# 57       81      New customer                 5
# 58       82  Regular customer                 1
# 59       82  Regular customer                 3

# %% [markdown]
# ### 06. Export file

# %%
#Export df_merged to pickle
ords_prods_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_grouped_data.pkl'))
